# %% [markdown]
# # <i class="fa fa-laptop"></i> Using Python for a summary of the results
#
# <div style="background-color: #86CBBB; 1px; height:3px " ></div>
#
# Here, we will demonstrate how to use python for some basic summary of the statistics of the Tresults generated in the CodeTheFly execise.
#
# In this Jupyter _notebook_ you can check and practice the exercises and some statistics from the previous practical session.

# %% [markdown]
# ## Step 0: Understand pandas dataframes

# %% [markdown]
# **_Pandas Dataframes_**
#
# [pandas](https://pandas.pydata.org/docs/index.html#module-pandas) is a library providing high-performance, easy-to-use data structures and data analysis tools.
#
# Dataframes contain:
# - Data organized in 2 dimensions, rows and columns
# - Labels that correspond to the rows and columns
#
# Pandas dataframe:
# - has functions for analyzing, exploring, and manipulating data.
# - can clean messy data sets (missing, NULL, wrong values), and make them readable and relevant.
# - allows us to analyze big data and make conclusions based on statistical theories.
#
#
#
# Additional details [here](https://realpython.com/pandas-dataframe/) and tutorials [there](https://www.w3schools.com/python/pandas/default.asp)
#
# ### <i class="fa fa-search"></i> Example

# %%
# import package
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)

# %% [markdown]
# #### Use alias to import pandas
#
# You can also use an alias.
#
# In Python alias are an alternate name for referring to the same thing.
#
# Now the Pandas package can be referred to as `pd` instead of `pandas`.

# %%
# import package and use abbreviation
import pandas as pd

data = {
    'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
    'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai','Manchester', 'Cairo', 'Osaka'],
    'age': [41, 28, 33, 34, 38, 31, 37],
    'py-score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]
}

row_labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

df = pd.DataFrame(data=data, index=row_labels)

df

# %%
## find index IDs
df.index

# %%
## find column IDs
df.columns

# %%
## access columns
df['city']

# %% [markdown]
# If the name of the column is a string that is a valid Python identifier, then you can use dot notation to access it. That is, you can access the column the same way you would get the attribute of a class instance:

# %%
## access columns too
df.city

# %% [markdown]
# Also, pandas has four accessors in total:
#
# - `.loc[]` accepts the labels of rows and columns and returns Series or DataFrames. You can use it to get entire rows or columns, as well as their parts.
#
# - `.iloc[]` accepts the zero-based indices of rows and columns and returns Series or DataFrames. You can use it to get entire rows or columns, or their parts.
#
# - `.at[]` accepts the labels of rows and columns and returns a single data value.
#
# - `.iat[]` accepts the zero-based indices of rows and columns and returns a single data value.

# %%
## Access the row named A
df.loc['A']

# %%
## Access a row using zero-based indices
df.iloc[2]

# %% [markdown]
# #### Slicing dataframes
# `.loc[]` and `.iloc[]` are particularly powerful. They support slicing and NumPy-style indexing. You can use them to access a column:

# %%
## PROVIDE: ROWS , COLUMNS
df.loc[ ['A', 'D'], ['city','age']]

# %%
## slicing dataframe: from 0-3rd row, only 0-2nd columns included
df.iloc[:3,:2]

# %% [markdown]
# ## Step 1: Read and inspect the file Tresults

# %% [markdown]
# In the following code chunk, we will create an alias for pandas named pd.
#
# We will use a function `read_csv` to read the content of the tabular separated file (Tresults) automatically into a dataframe.
#
# Note the argument `sep="\t"` that tells python to split columns by `\t` and not `,` (as it should do it for the comma separated values).

# %%
import pandas as pd

# %% [markdown]
# ### Read file

# %% [markdown]
# **ATTENTION**: Modify if necessary in the following code, the variable `file_Tresults`, to the path to your file Tresults obtained.

# %%
file_Tresults = "./Tresults"
example_res = pd.read_csv(file_Tresults, sep="\t")

# %%
# example_res is a dataframe == Excel table
type(example_res)
# Out:
# pandas.core.frame.DataFrame

# %%
## get a small subset of the first lines
example_res.head()
# Out:
#       strain           TE absence_detection presence_detection  combination  \
# 0  SRR202127  FBti0063191           present            present      present
# 1  SRR202127  FBti0020145            absent             absent       absent
# 2  SRR202127  FBti0019327               NaN            present  polymorphic
# 3  SRR202127  FBti0018908           present            present      present
# 4  SRR202127  FBti0019782               NaN            present  polymorphic
#
#    read_number_absence  left_match_length left_match_id polyAT_left  \
# 0                  0.0                 60   98.33(1/60)         NaN
# 1                  7.0                 -2        0(0/0)         NaN
# 2                  NaN                 60   96.67(2/60)         NaN
# 3                  0.0                 60   98.33(1/60)         NaN
# 4                  NaN                 60  100.00(0/60)         NaN
#
#    left_coverage   left_repeat  left_read_number_presence  \
# 0          14.86  Gypsy12A_LTR                          9
# 1           2.52           NaN                          0
# 2          32.83           NaN                         19
# 3          13.53           NaN                          5
# 4          24.63      (ATATC)n                         19
#
#    left_filtered_read_number_presence  right_match_length right_match_id  \
# 0                                   9                  60    96.67(2/60)
# 1                                   0                 -30         0(0/0)
# 2                                  19                  60   100.00(0/60)
# 3                                   5                  60    98.33(1/60)
# 4                                  19                  60   100.00(0/60)
#
#   polyAT_right  right_coverage   right_repeat  right_read_number_presence  \
# 0          NaN           12.68            NaN                           8
# 1     poly(A)4            0.55            NaN                           0
# 2          NaN           19.88    BEL-1_DBi-I                          12
# 3          NaN           27.34  Gypsy-2_DAn-I                          22
# 4          NaN           25.69   Jockey-3_DBp                          12
#
#    right_filtered_read_number_presence
# 0                                    8
# 1                                    0
# 2                                   12
# 3                                   22
# 4                                   12

# %%
## get a small subset of the last lines
example_res.tail()
# Out:
#          strain           TE absence_detection presence_detection  \
# 1626  SRR202127  FBti0063125               NaN             absent
# 1627  SRR202127  FBti0061008           present            present
# 1628  SRR202127  FBti0064097               NaN            present
# 1629  SRR202127  FBti0063263           present            present
# 1630  SRR202127  FBti0064176           present            present
#
#       combination  read_number_absence  left_match_length left_match_id  \
# 1626      no_data                  NaN                 -1        0(0/0)
# 1627      present                  0.0                 60  100.00(0/60)
# 1628  polymorphic                  NaN                 60  100.00(0/60)
# 1629      present                  0.0                 60  100.00(0/60)
# 1630      present                  0.0                 60   98.33(1/60)
#
#      polyAT_left  left_coverage     left_repeat  left_read_number_presence  \
# 1626         NaN          15.26  Gypsy-17_DTa-I                          0
# 1627    poly(A)4           8.56             NaN                          4
# 1628         NaN           6.50   Gypsy-3_DSe-I                          3
# 1629         NaN           4.99             NaN                          3
# 1630         NaN          21.49             NaN                         13
#
#       left_filtered_read_number_presence  right_match_length right_match_id  \
# 1626                                   0                   0         0(0/0)
# 1627                                   4                  60   100.00(0/60)
# 1628                                   3                  60   100.00(0/60)
# 1629                                   3                  60   100.00(0/60)
# 1630                                  13                  60    98.33(1/60)
#
#      polyAT_right  right_coverage    right_repeat  right_read_number_presence  \
# 1626          NaN           11.77  Gypsy-17_DTa-I                           0
# 1627          NaN           10.62             NaN                           4
# 1628          NaN           20.87     BEL-1_DRh-I                          14
# 1629          NaN            6.69             NaN                           6
# 1630          NaN           95.92             NaN                          43
#
#       right_filtered_read_number_presence
# 1626                                    0
# 1627                                    4
# 1628                                   14
# 1629                                    6
# 1630                                   43

# %% [markdown]
# ### Describe information within file

# %%
## get the number of dimensions of the dataframe
example_res.shape
# Out:
# (1631, 20)

# %% [markdown]
# We can get the types of values in each of the 20 columns:
# - object: character strings (A, B, C, ABC, "a string"...)
# - int64: an integer number: 1,2,3,4,5...
# - float64: a decimal numnber: 0.963, 0.121, 124.156...

# %%
## obtain the types of values
example_res.dtypes
# Out:
# strain                                  object
# TE                                      object
# absence_detection                       object
# presence_detection                      object
# combination                             object
# read_number_absence                    float64
# left_match_length                        int64
# left_match_id                           object
# polyAT_left                             object
# left_coverage                          float64
# left_repeat                             object
# left_read_number_presence                int64
# left_filtered_read_number_presence       int64
# right_match_length                       int64
# right_match_id                          object
# polyAT_right                            object
# right_coverage                         float64
# right_repeat                            object
# right_read_number_presence               int64
# right_filtered_read_number_presence      int64
# dtype: object

# %%
# pandas built-in function describe allows to summarize float and integers automatically
example_res.describe()
# Out:
#        read_number_absence  left_match_length  left_coverage  \
# count          1207.000000        1631.000000    1631.000000
# mean              7.798674          26.228081      11.595512
# std              11.311879          35.859381      11.490273
# min               0.000000         -30.000000       0.000000
# 25%               0.000000          -3.000000       3.565000
# 50%               0.000000          60.000000       7.780000
# 75%              14.000000          60.000000      16.060000
# max              72.000000          60.000000      76.470000
#
#        left_read_number_presence  left_filtered_read_number_presence  \
# count                1631.000000                         1631.000000
# mean                    5.663397                            5.629062
# std                     8.547098                            8.541439
# min                     0.000000                            0.000000
# 25%                     0.000000                            0.000000
# 50%                     0.000000                            0.000000
# 75%                     9.000000                            9.000000
# max                    60.000000                           60.000000
#
#        right_match_length  right_coverage  right_read_number_presence  \
# count         1631.000000     1631.000000                 1631.000000
# mean            25.639485       11.450497                    5.690374
# std             36.461645       11.916193                    8.737503
# min            -30.000000        0.000000                    0.000000
# 25%             -4.000000        3.330000                    0.000000
# 50%             59.000000        7.270000                    0.000000
# 75%             60.000000       15.750000                    9.000000
# max             60.000000       95.920000                   59.000000
#
#        right_filtered_read_number_presence
# count                          1631.000000
# mean                              5.648069
# std                               8.713363
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               9.000000
# max                              59.000000

# %%
## count number of occurrences for the elements of a string column
example_res['absence_detection'].value_counts()
# Out:
# present    602
# absent     597
# no_data      8
# Name: absence_detection, dtype: int64

# %%
## access the values of the column combination
example_res.combination
# Out:
# 0           present
# 1            absent
# 2       polymorphic
# 3           present
# 4       polymorphic
#            ...
# 1626        no_data
# 1627        present
# 1628    polymorphic
# 1629        present
# 1630        present
# Name: combination, Length: 1631, dtype: object

# %%
# we can select columns which are strings, objects
example_res.select_dtypes(include=['object'])
# Out:
#          strain           TE absence_detection presence_detection  \
# 0     SRR202127  FBti0063191           present            present
# 1     SRR202127  FBti0020145            absent             absent
# 2     SRR202127  FBti0019327               NaN            present
# 3     SRR202127  FBti0018908           present            present
# 4     SRR202127  FBti0019782               NaN            present
# ...         ...          ...               ...                ...
# 1626  SRR202127  FBti0063125               NaN             absent
# 1627  SRR202127  FBti0061008           present            present
# 1628  SRR202127  FBti0064097               NaN            present
# 1629  SRR202127  FBti0063263           present            present
# 1630  SRR202127  FBti0064176           present            present
#
#       combination left_match_id polyAT_left     left_repeat right_match_id  \
# 0         present   98.33(1/60)         NaN    Gypsy12A_LTR    96.67(2/60)
# 1          absent        0(0/0)         NaN             NaN         0(0/0)
# 2     polymorphic   96.67(2/60)         NaN             NaN   100.00(0/60)
# 3         present   98.33(1/60)         NaN             NaN    98.33(1/60)
# 4     polymorphic  100.00(0/60)         NaN        (ATATC)n   100.00(0/60)
# ...           ...           ...         ...             ...            ...
# 1626      no_data        0(0/0)         NaN  Gypsy-17_DTa-I         0(0/0)
# 1627      present  100.00(0/60)    poly(A)4             NaN   100.00(0/60)
# 1628  polymorphic  100.00(0/60)         NaN   Gypsy-3_DSe-I   100.00(0/60)
# 1629      present  100.00(0/60)         NaN             NaN   100.00(0/60)
# 1630      present   98.33(1/60)         NaN             NaN    98.33(1/60)
#
#      polyAT_right    right_repeat
# 0             NaN             NaN
# 1        poly(A)4             NaN
# 2             NaN     BEL-1_DBi-I
# 3             NaN   Gypsy-2_DAn-I
# 4             NaN    Jockey-3_DBp
# ...           ...             ...
# 1626          NaN  Gypsy-17_DTa-I
# 1627          NaN             NaN
# 1628          NaN     BEL-1_DRh-I
# 1629          NaN             NaN
# 1630          NaN             NaN
#
# [1631 rows x 11 columns]

# %%
# we can select columns which are numbers
example_res.select_dtypes(include=['float', 'int'])
# Out:
#       read_number_absence  left_match_length  left_coverage  \
# 0                     0.0                 60          14.86
# 1                     7.0                 -2           2.52
# 2                     NaN                 60          32.83
# 3                     0.0                 60          13.53
# 4                     NaN                 60          24.63
# ...                   ...                ...            ...
# 1626                  NaN                 -1          15.26
# 1627                  0.0                 60           8.56
# 1628                  NaN                 60           6.50
# 1629                  0.0                 60           4.99
# 1630                  0.0                 60          21.49
#
#       left_read_number_presence  left_filtered_read_number_presence  \
# 0                             9                                   9
# 1                             0                                   0
# 2                            19                                  19
# 3                             5                                   5
# 4                            19                                  19
# ...                         ...                                 ...
# 1626                          0                                   0
# 1627                          4                                   4
# 1628                          3                                   3
# 1629                          3                                   3
# 1630                         13                                  13
#
#       right_match_length  right_coverage  right_read_number_presence  \
# 0                     60           12.68                           8
# 1                    -30            0.55                           0
# 2                     60           19.88                          12
# 3                     60           27.34                          22
# 4                     60           25.69                          12
# ...                  ...             ...                         ...
# 1626                   0           11.77                           0
# 1627                  60           10.62                           4
# 1628                  60           20.87                          14
# 1629                  60            6.69                           6
# 1630                  60           95.92                          43
#
#       right_filtered_read_number_presence
# 0                                       8
# 1                                       0
# 2                                      12
# 3                                      22
# 4                                      12
# ...                                   ...
# 1626                                    0
# 1627                                    4
# 1628                                   14
# 1629                                    6
# 1630                                   43
#
# [1631 rows x 9 columns]

# %%
## count number of occurrences for the elements of a string column
example_res['combination'].value_counts()
# Out:
# absent         527
# present        488
# polymorphic    356
# no_data        260
# Name: combination, dtype: int64

# %%
## create a plot representation
example_res['combination'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Inspect regions around repeats

# %% [markdown]
# Sometimes, at the left and right side of the transposon, there is a repeat.
#
# Which are the most common ones?

# %%
# get the summary of the elements in the left_repeat column
example_res['left_repeat'].value_counts()
# Out:
# DNAREP1_DSim      48
# (TA)n             17
# A-rich            15
# DNAREP1_DM        13
# Gypsy-1_DSim-I    12
#                   ..
# (ACTTT)n           1
# LSU-rRNA_Dme       1
# (AAGAACA)n         1
# G5_DM              1
# Gypsy-3_DSe-I      1
# Name: left_repeat, Length: 237, dtype: int64

# %%
# get the summary of the elements in the right_repeat column
example_res['right_repeat'].value_counts()
# Out:
# DNAREP1_DSim      50
# DNAREP1_DM        18
# DNAREP1_DYak      13
# A-rich            11
# (TA)n              9
#                   ..
# (AAGAACA)n         1
# Gypsy21-I_Dpse     1
# hAT-2_DSe          1
# (TTATCA)n          1
# Gypsy-17_DTa-I     1
# Name: right_repeat, Length: 202, dtype: int64

# %%
# get the summary of the elements in the right_repeat column
example_res['polyAT_right'].value_counts()
# Out:
# poly(A)4     15
# poly(A)5      6
# poly(A)6      4
# poly(A)7      3
# poly(A)15     1
# poly(A)13     1
# poly(A)12     1
# poly(A)8      1
# poly(A)17     1
# poly(A)10     1
# poly(A)9      1
# Name: polyAT_right, dtype: int64

# %% [markdown]
# ## Analyze some of the results analyzed within the CodeFly Project

# %% [markdown]
# Accompanying this python jupyter notebook there is a file named as all_results.tsv that contains the results for several different SRA samples.

# %%
example_res_all = pd.read_csv("Tresults-all", sep="\t")

# %%
example_res_all.shape
# Out:
# (185934, 20)

# %%
example_res_all.head()
# Out:
#       strain           TE absence_detection presence_detection  combination  \
# 0  SRR189423  FBti0020073            absent             absent       absent
# 1  SRR189423  FBti0062239               NaN            present  polymorphic
# 2  SRR189423  FBti0019138            absent             absent       absent
# 3  SRR189423  FBti0019236           present             absent      no_data
# 4  SRR189423  FBti0020278           present            present      present
#
#    read_number_absence  left_match_length left_match_id polyAT_left  \
# 0                 14.0                  2   100.00(0/2)         NaN
# 1                  NaN                 60  100.00(0/60)         NaN
# 2                 14.0                  1   100.00(0/1)         NaN
# 3                  0.0                 -9        0(0/0)         NaN
# 4                  0.0                 60  100.00(0/60)         NaN
#
#    left_coverage    left_repeat  left_read_number_presence  \
# 0           5.21            NaN                          0
# 1          16.74  Gypsy12-I_Dya                          8
# 2           8.54            NaN                          0
# 3           1.21            NaN                          0
# 4          18.76            NaN                         14
#
#    left_filtered_read_number_presence  right_match_length right_match_id  \
# 0                                   0                   1    100.00(0/1)
# 1                                   8                  60   100.00(0/60)
# 2                                   0                   1    100.00(0/1)
# 3                                   0                  -1         0(0/0)
# 4                                  14                  60   100.00(0/60)
#
#   polyAT_right  right_coverage   right_repeat  right_read_number_presence  \
# 0          NaN            2.01            NaN                           0
# 1          NaN           18.85  Gypsy12-I_Dya                          19
# 2          NaN            4.70            NaN                           0
# 3          NaN            7.52            NaN                           0
# 4          NaN           11.82            NaN                           1
#
#    right_filtered_read_number_presence
# 0                                    0
# 1                                   19
# 2                                    0
# 3                                    0
# 4                                    1

# %%
example_res_all.tail()
# Out:
#             strain           TE absence_detection presence_detection  \
# 185929  SRR5762812  FBti0019390            absent             absent
# 185930  SRR5762812  FBti0060368           present            present
# 185931  SRR5762812  FBti0062259           present            present
# 185932  SRR5762812  FBti0020209            absent            present
# 185933  SRR5762812  FBti0019338            absent             absent
#
#         combination  read_number_absence  left_match_length left_match_id  \
# 185929       absent                 20.0                 -1        0(0/0)
# 185930      present                  0.0                 60  100.00(0/60)
# 185931      present                  0.0                 60  100.00(0/60)
# 185932  polymorphic                 14.0                 60  100.00(0/60)
# 185933       absent                 23.0                 -1        0(0/0)
#
#        polyAT_left  left_coverage left_repeat  left_read_number_presence  \
# 185929         NaN           8.81         NaN                          0
# 185930         NaN          27.89         NaN                         19
# 185931         NaN          34.56         NaN                         26
# 185932         NaN          12.11         NaN                          5
# 185933         NaN           5.12         NaN                          0
#
#         left_filtered_read_number_presence  right_match_length right_match_id  \
# 185929                                   0                   1    100.00(0/1)
# 185930                                  19                  60   100.00(0/60)
# 185931                                  26                  60   100.00(0/60)
# 185932                                   5                  60   100.00(0/60)
# 185933                                   0                   0         0(0/0)
#
#        polyAT_right  right_coverage right_repeat  right_read_number_presence  \
# 185929          NaN            2.96   (CAGCATC)n                           0
# 185930          NaN           18.43          NaN                          11
# 185931          NaN           35.81        (TG)n                          25
# 185932          NaN            9.03          NaN                           5
# 185933          NaN            8.26          NaN                           0
#
#         right_filtered_read_number_presence
# 185929                                    0
# 185930                                   11
# 185931                                   25
# 185932                                    5
# 185933                                    0

# %% [markdown]
# We can get unique values for column strain, this should be the 100 samples included

# %%
## get unique values for column strain
set(example_res_all.strain)
# Out:
# {'SRR189423',
#  'SRR189424',
#  'SRR189426',
#  'SRR202075',
#  'SRR202076',
#  'SRR202077',
#  'SRR202078',
#  'SRR202079',
#  'SRR202080',
#  'SRR202081',
#  'SRR202082',
#  'SRR202083',
#  'SRR202085',
#  'SRR202089',
#  'SRR202093',
#  'SRR202094',
#  'SRR202095',
#  'SRR202099',
#  'SRR202100',
#  'SRR202112',
#  'SRR202123',
#  'SRR202124',
#  'SRR202125',
#  'SRR202126',
#  'SRR202127',
#  'SRR202128',
#  'SRR202129',
#  'SRR203064',
#  'SRR203067',
#  'SRR203068',
#  'SRR203069',
#  'SRR203226',
#  'SRR203227',
#  'SRR203228',
#  'SRR203229',
#  'SRR203230',
#  'SRR203231',
#  'SRR203232',
#  'SRR203233',
#  'SRR203234',
#  'SRR203235',
#  'SRR203236',
#  'SRR203237',
#  'SRR203238',
#  'SRR2033112',
#  'SRR2033113',
#  'SRR2033114',
#  'SRR2033115',
#  'SRR2033116',
#  'SRR2033117',
#  'SRR2033118',
#  'SRR2033119',
#  'SRR2033120',
#  'SRR2033121',
#  'SRR2033122',
#  'SRR2033123',
#  'SRR2033124',
#  'SRR2033126',
#  'SRR2033127',
#  'SRR2033128',
#  'SRR2033129',
#  'SRR2033130',
#  'SRR2033131',
#  'SRR2033132',
#  'SRR2033133',
#  'SRR2033134',
#  'SRR2033135',
#  'SRR2033136',
#  'SRR2033137',
#  'SRR2033138',
#  'SRR2033139',
#  'SRR2033140',
#  'SRR2033141',
#  'SRR2033142',
#  'SRR2033143',
#  'SRR2033144',
#  'SRR2033146',
#  'SRR2033147',
#  'SRR2033148',
#  'SRR2033149',
#  'SRR2033150',
#  'SRR2033151',
#  'SRR2033152',
#  'SRR2033153',
#  'SRR2033154',
#  'SRR2033155',
#  'SRR2033156',
#  'SRR2033157',
#  'SRR2033158',
#  'SRR2033159',
#  'SRR2033160',
#  'SRR2033161',
#  'SRR2033162',
#  'SRR2033163',
#  'SRR2033164',
#  'SRR2033165',
#  'SRR2033166',
#  'SRR2033167',
#  'SRR2033168',
#  'SRR2033169',
#  'SRR2033170',
#  'SRR5762771',
#  'SRR5762773',
#  'SRR5762774',
#  'SRR5762775',
#  'SRR5762776',
#  'SRR5762778',
#  'SRR5762806',
#  'SRR5762807',
#  'SRR5762808',
#  'SRR5762809',
#  'SRR5762810',
#  'SRR5762811',
#  'SRR5762812'}

# %%
## get how many unique strain have been analyzed
len(set(example_res_all.strain))
# Out:
# 114

# %% [markdown]
# We can get the values for all samples and an example transposon

# %%
## subset the dataframe with a given value for a column: TE=FBti0063675
example_res_all[example_res_all['TE']=='FBti0063675']
# Out:
#             strain           TE absence_detection presence_detection  \
# 1125     SRR189423  FBti0063675           present            present
# 1767     SRR189424  FBti0063675           present            present
# 3276     SRR189426  FBti0063675           present            present
# 5202     SRR202075  FBti0063675           present            present
# 8131     SRR202076  FBti0063675           no_data            present
# ...            ...          ...               ...                ...
# 178619  SRR5762808  FBti0063675           present            present
# 179959  SRR5762809  FBti0063675           present             absent
# 181818  SRR5762810  FBti0063675           present            present
# 184078  SRR5762811  FBti0063675           present            present
# 184613  SRR5762812  FBti0063675           present            present
#
#        combination  read_number_absence  left_match_length left_match_id  \
# 1125       present                  0.0                 60  100.00(0/60)
# 1767       present                  0.0                 60   96.67(2/60)
# 3276       present                  0.0                 60  100.00(0/60)
# 5202       present                  0.0                 60  100.00(0/60)
# 8131       no_data                  0.0                 60   96.67(2/60)
# ...            ...                  ...                ...           ...
# 178619     present                  0.0                 60   96.67(2/60)
# 179959     no_data                  0.0                 60   93.33(4/60)
# 181818     present                  0.0                 60   95.00(3/60)
# 184078     present                  0.0                 60   95.00(3/60)
# 184613     present                  0.0                 60   95.00(3/60)
#
#        polyAT_left  left_coverage left_repeat  left_read_number_presence  \
# 1125           NaN          28.52         NaN                         25
# 1767           NaN           8.35         NaN                         12
# 3276           NaN          21.96         NaN                         15
# 5202           NaN          24.80         NaN                         14
# 8131           NaN           5.67         NaN                          7
# ...            ...            ...         ...                        ...
# 178619         NaN          25.59         NaN                         16
# 179959         NaN          17.95         NaN                         15
# 181818         NaN          23.44         NaN                         11
# 184078         NaN          23.09         NaN                         19
# 184613         NaN          28.06         NaN                         28
#
#         left_filtered_read_number_presence  right_match_length right_match_id  \
# 1125                                    25                  60   100.00(0/60)
# 1767                                    12                  60    95.00(3/60)
# 3276                                    15                  60   100.00(0/60)
# 5202                                    14                  60   100.00(0/60)
# 8131                                     7                  60    95.00(3/60)
# ...                                    ...                 ...            ...
# 178619                                  16                  60    93.33(4/60)
# 179959                                   0                  60    91.67(5/60)
# 181818                                  11                  60    93.33(4/60)
# 184078                                  19                  60    91.67(5/60)
# 184613                                  28                  60    93.33(4/60)
#
#        polyAT_right  right_coverage right_repeat  right_read_number_presence  \
# 1125            NaN           20.93          NaN                          11
# 1767            NaN            9.79          NaN                          10
# 3276            NaN           16.33          NaN                           9
# 5202            NaN           21.81          NaN                          18
# 8131            NaN           10.11          NaN                           8
# ...             ...             ...          ...                         ...
# 178619          NaN           32.68          NaN                          32
# 179959          NaN           17.82          NaN                          14
# 181818          NaN           31.82          NaN                          33
# 184078          NaN           27.12          NaN                          24
# 184613          NaN           33.39          NaN                          26
#
#         right_filtered_read_number_presence
# 1125                                     11
# 1767                                     10
# 3276                                      9
# 5202                                     18
# 8131                                      8
# ...                                     ...
# 178619                                   32
# 179959                                    0
# 181818                                   33
# 184078                                   24
# 184613                                   26
#
# [114 rows x 20 columns]

# %% [markdown]
# We can produce some summary results for the samples

# %%
## count values for each level in the combination column
example_res_all['combination'].value_counts()
# Out:
# polymorphic    74114
# present        65062
# absent         34841
# no_data        11917
# Name: combination, dtype: int64

# %% [markdown]
# By doing the previous code, we are obtaining the summary of all values for all samples, but we might be interested in obtaining grouped by each sample

# %%
## Group by sample and count the combination levels: absent, no_data, polymorphic, present, absent
example_res_all.groupby(['strain', 'combination'])['combination'].agg(['count'])
# Out:
#                         count
# strain     combination
# SRR189423  absent         549
#            no_data        216
#            polymorphic    367
#            present        499
# SRR189424  absent         554
# ...                       ...
# SRR5762811 present        536
# SRR5762812 absent         554
#            no_data         80
#            polymorphic    463
#            present        534
#
# [456 rows x 1 columns]

# %%
## unstack and pivot the table to better understand the results
summary_data = example_res_all.groupby(['strain', 'combination'])['combination'].agg(['count']).unstack()
summary_data
# Out:
#              count
# combination absent no_data polymorphic present
# strain
# SRR189423      549     216         367     499
# SRR189424      554     212         362     503
# SRR189426      566     189         370     506
# SRR202075      556     213         363     499
# SRR202076      564     189         370     508
# ...            ...     ...         ...     ...
# SRR5762808     565      83         454     529
# SRR5762809     559      95         447     530
# SRR5762810     565     100         432     534
# SRR5762811     553      90         452     536
# SRR5762812     554      80         463     534
#
# [114 rows x 4 columns]

# %% [markdown]
# We are going to create a plot for all samples, one in each column and the stacked values of the different levels of combination parameters

# %%
## plot the results of the combination column group by strain and summarized
example_res_all.groupby('strain')['combination'].value_counts().unstack().plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='strain'>

# %% [markdown]
# Note that there is a particular clustering of the samples, following alphabetical order due to sampling location. The clustering corresponds with similar distributions of transposons, it is expected as samples from same locations share a genetic background.

# %% [markdown]
# ### Inspect a set of particular transposons of interest

# %% [markdown]
# Are FBti0019627, FBti0019985 & FBti0019386 present in any of the samples? Which one is the most frequent one?

# %%
## subset the dataframe with a given value for a column: TE=FBti0063675
subset_df = example_res_all[example_res_all['TE'].isin(['FBti0019627', 'FBti0019985', 'FBti0019386'])]
subset_df
# Out:
#             strain           TE absence_detection presence_detection  \
# 50       SRR189423  FBti0019627            absent             absent
# 296      SRR189423  FBti0019386            absent             absent
# 650      SRR189423  FBti0019985            absent            present
# 1742     SRR189424  FBti0019627            absent             absent
# 2122     SRR189424  FBti0019386            absent             absent
# ...            ...          ...               ...                ...
# 183540  SRR5762811  FBti0019386            absent            present
# 183728  SRR5762811  FBti0019627            absent            present
# 184473  SRR5762812  FBti0019386            absent            present
# 184712  SRR5762812  FBti0019627            absent            present
# 185724  SRR5762812  FBti0019985            absent             absent
#
#         combination  read_number_absence  left_match_length left_match_id  \
# 50           absent                 20.0                 -1        0(0/0)
# 296          absent                 19.0                  1   100.00(0/1)
# 650     polymorphic                  8.0                  2   100.00(0/2)
# 1742         absent                 18.0                 -1        0(0/0)
# 2122         absent                 14.0                 -1        0(0/0)
# ...             ...                  ...                ...           ...
# 183540  polymorphic                  9.0                 60  100.00(0/60)
# 183728  polymorphic                  8.0                 60  100.00(0/60)
# 184473  polymorphic                 12.0                 60  100.00(0/60)
# 184712  polymorphic                 13.0                 60  100.00(0/60)
# 185724       absent                 17.0                -30        0(0/0)
#
#        polyAT_left  left_coverage left_repeat  left_read_number_presence  \
# 50             NaN           4.48         NaN                          0
# 296            NaN           4.88         NaN                          0
# 650            NaN           3.10         NaN                          0
# 1742           NaN           3.45         NaN                          0
# 2122           NaN           6.00         NaN                          0
# ...            ...            ...         ...                        ...
# 183540         NaN          17.34         NaN                         10
# 183728         NaN          27.33         NaN                         12
# 184473         NaN          23.69         NaN                         14
# 184712         NaN          11.84         NaN                          4
# 185724         NaN           0.23         NaN                          0
#
#         left_filtered_read_number_presence  right_match_length right_match_id  \
# 50                                       0                  -8         0(0/0)
# 296                                      0                  -1         0(0/0)
# 650                                      0                  49   100.00(0/49)
# 1742                                     0                  -2         0(0/0)
# 2122                                     0                   0         0(0/0)
# ...                                    ...                 ...            ...
# 183540                                  10                  60   100.00(0/60)
# 183728                                  12                  60   100.00(0/60)
# 184473                                  14                  60   100.00(0/60)
# 184712                                   4                  60   100.00(0/60)
# 185724                                   0                  -2         0(0/0)
#
#        polyAT_right  right_coverage right_repeat  right_read_number_presence  \
# 50              NaN            5.88          NaN                           0
# 296             NaN            2.60          NaN                           0
# 650             NaN            7.51          NaN                           1
# 1742            NaN            2.21          NaN                           0
# 2122            NaN            4.46          NaN                           0
# ...             ...             ...          ...                         ...
# 183540          NaN           16.27          NaN                          11
# 183728          NaN           34.56          NaN                          21
# 184473          NaN           25.54          NaN                          14
# 184712          NaN           12.16          NaN                           5
# 185724          NaN            4.34          NaN                           0
#
#         right_filtered_read_number_presence
# 50                                        0
# 296                                       0
# 650                                       1
# 1742                                      0
# 2122                                      0
# ...                                     ...
# 183540                                   11
# 183728                                   21
# 184473                                   14
# 184712                                    5
# 185724                                    0
#
# [342 rows x 20 columns]

# %%
## unstack and pivot the table to better understand the results
subset_df.pivot_table(index='TE', columns='combination', values='strain', aggfunc='count', fill_value=0)
# Out:
# combination  absent  no_data  polymorphic  present
# TE
# FBti0019386      46        1           26       41
# FBti0019627      44        0           50       20
# FBti0019985      38       14           62        0

# %%
## unstack and pivot the table to better understand the results
subset_df.pivot_table(index='TE', columns='combination', values='strain', aggfunc='count', fill_value=0).plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='TE'>
